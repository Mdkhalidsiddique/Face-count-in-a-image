# %%
import face_recognition as fr

# %%
image = fr.load_image_file("pics.jpg")

# %%
fl = fr.face_locations(image)

# %%
print(fl)
# Out:
# [(696, 366, 882, 180), (494, 666, 649, 511), (736, 765, 1003, 498), (236, 373, 391, 218)]

# %%
from IPython.display import Image

# %%
Image(filename='pics.jpg')

# %%
print(f'There are {len(fl)} people in this image')
# Out:
# There are 4 people in this image
